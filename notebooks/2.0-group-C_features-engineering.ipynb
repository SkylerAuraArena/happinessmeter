# %%
import pandas as pd 

# On importe le fichier créé à l'étape de data visualisation.
df=pd.read_csv('../data/df_global.csv')

df.head()
# Out:
#   Country name Regional indicator  year  Life Ladder  Log GDP per capita  \
# 0  Afghanistan         South Asia  2008        3.724               7.370
# 1  Afghanistan         South Asia  2009        4.402               7.540
# 2  Afghanistan         South Asia  2010        4.758               7.647
# 3  Afghanistan         South Asia  2011        3.832               7.620
# 4  Afghanistan         South Asia  2012        3.783               7.705
#
#    Social support  Healthy life expectancy at birth  \
# 0           0.451                             50.80
# 1           0.552                             51.20
# 2           0.539                             51.60
# 3           0.521                             51.92
# 4           0.521                             52.24
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.718       0.168                      0.882
# 1                         0.679       0.190                      0.850
# 2                         0.600       0.121                      0.707
# 3                         0.496       0.162                      0.731
# 4                         0.531       0.236                      0.776
#
#    Positive affect  Negative affect
# 0            0.518            0.258
# 1            0.584            0.237
# 2            0.618            0.275
# 3            0.611            0.267
# 4            0.710            0.268

# %%
# Le dataset a déjà été nettoyé (ni valeur manquante, ni doublon).

# Les colonnes 'Country name' et 'year' sont enlevé car elle n'apporte pas de valeur particulière au modèle.
df_forML = df.drop(['Country name','year'],axis=1)
df_forML.head()
# Out:
#   Regional indicator  Life Ladder  Log GDP per capita  Social support  \
# 0         South Asia        3.724               7.370           0.451
# 1         South Asia        4.402               7.540           0.552
# 2         South Asia        4.758               7.647           0.539
# 3         South Asia        3.832               7.620           0.521
# 4         South Asia        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# 0                      0.882            0.518            0.258
# 1                      0.850            0.584            0.237
# 2                      0.707            0.618            0.275
# 3                      0.731            0.611            0.267
# 4                      0.776            0.710            0.268

# %%
# On enregistre le dataset dans un fichier CSV.
df_forML.to_csv('../data/df_ml.csv', index=False)

# %%
# Séparation des paramètres et de la variable cible.
params = df_forML.drop('Life Ladder', axis=1)
target = df_forML['Life Ladder']

# %%
# Instanciation des jeux d'entraînement et de test. 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(params,
                                                    target,
                                                    test_size=0.2,
                                                    random_state=42)

# %%
X_train.head()
# Out:
#                 Regional indicator  Log GDP per capita  Social support  \
# 1591  Middle East and North Africa              10.798           0.820
# 1379            Sub-Saharan Africa               8.484           0.739
# 414             Sub-Saharan Africa               8.136           0.621
# 704    Latin America and Caribbean               8.935           0.802
# 755                      East Asia              10.887           0.846
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1591                             65.40                         0.820
# 1379                             50.50                         0.713
# 414                              57.90                         0.699
# 704                              62.82                         0.865
# 755                              76.82                         0.894
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# 1591      -0.045                     0.5065            0.724            0.327
# 1379       0.099                     0.9130            0.744            0.316
# 414       -0.092                     0.7380            0.588            0.448
# 704        0.020                     0.8210            0.863            0.349
# 755        0.235                     0.2450            0.734            0.196

# %%
# utilisation du OneHotEncoder
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder(drop="first", sparse=False)

# Adaptation de l'encodeur aux données d'entraînement
encoded_train = ohe.fit_transform(X_train[['Regional indicator']])

# Transformation des données de test
encoded_test = ohe.transform(X_test[['Regional indicator']])

# Remplacement des colonnes originales par les nouvelles colonnes transformées
cat_train = pd.DataFrame(encoded_train, columns=ohe.get_feature_names_out(['Regional indicator']), index=X_train.index)
cat_test = pd.DataFrame(encoded_test, columns=ohe.get_feature_names_out(['Regional indicator']), index=X_test.index)
# Out:
# /Users/thevault/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
# Suppression de la colonne "Regional indicator dans les jeux d'entraînement et de test."
X_train = X_train.drop('Regional indicator', axis=1)
X_test = X_test.drop('Regional indicator', axis=1)

# %%
# Concaténation des jeux avec le jeu encodé
X_train = pd.concat([X_train,cat_train], axis = 1)
X_test = pd.concat([X_test,cat_test], axis = 1)

# %%
X_train
# Out:
#       Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 1591              10.798           0.820                            65.400
# 1379               8.484           0.739                            50.500
# 414                8.136           0.621                            57.900
# 704                8.935           0.802                            62.820
# 755               10.887           0.846                            76.820
# ...                  ...             ...                               ...
# 1638               7.449           0.611                            52.400
# 1095              11.592           0.952                            71.700
# 1130               6.958           0.537                            57.948
# 1294               7.686           0.818                            58.200
# 860               10.389           0.927                            71.120
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 1591                         0.820      -0.045                     0.5065
# 1379                         0.713       0.099                     0.9130
# 414                          0.699      -0.092                     0.7380
# 704                          0.865       0.020                     0.8210
# 755                          0.894       0.235                     0.2450
# ...                            ...         ...                        ...
# 1638                         0.718       0.074                     0.8740
# 1095                         0.908       0.096                     0.4230
# 1130                         0.780       0.038                     0.7290
# 1294                         0.618       0.291                     0.9000
# 860                          0.817       0.141                     0.9050
#
#       Positive affect  Negative affect  \
# 1591            0.724           0.3270
# 1379            0.744           0.3160
# 414             0.588           0.4480
# 704             0.863           0.3490
# 755             0.734           0.1960
# ...               ...              ...
# 1638            0.513           0.4380
# 1095            0.809           0.2160
# 1130            0.687           0.2615
# 1294            0.745           0.1530
# 860             0.696           0.3080
#
#       Regional indicator_Commonwealth of Independent States  \
# 1591                                                0.0
# 1379                                                0.0
# 414                                                 0.0
# 704                                                 0.0
# 755                                                 0.0
# ...                                                 ...
# 1638                                                0.0
# 1095                                                0.0
# 1130                                                0.0
# 1294                                                0.0
# 860                                                 0.0
#
#       Regional indicator_East Asia  \
# 1591                           0.0
# 1379                           0.0
# 414                            0.0
# 704                            0.0
# 755                            1.0
# ...                            ...
# 1638                           0.0
# 1095                           0.0
# 1130                           0.0
# 1294                           0.0
# 860                            0.0
#
#       Regional indicator_Latin America and Caribbean  \
# 1591                                             0.0
# 1379                                             0.0
# 414                                              0.0
# 704                                              1.0
# 755                                              0.0
# ...                                              ...
# 1638                                             0.0
# 1095                                             0.0
# 1130                                             0.0
# 1294                                             0.0
# 860                                              0.0
#
#       Regional indicator_Middle East and North Africa  \
# 1591                                              1.0
# 1379                                              0.0
# 414                                               0.0
# 704                                               0.0
# 755                                               0.0
# ...                                               ...
# 1638                                              0.0
# 1095                                              0.0
# 1130                                              0.0
# 1294                                              0.0
# 860                                               1.0
#
#       Regional indicator_North America and ANZ  Regional indicator_South Asia  \
# 1591                                       0.0                            0.0
# 1379                                       0.0                            0.0
# 414                                        0.0                            0.0
# 704                                        0.0                            0.0
# 755                                        0.0                            0.0
# ...                                        ...                            ...
# 1638                                       0.0                            0.0
# 1095                                       0.0                            0.0
# 1130                                       0.0                            0.0
# 1294                                       0.0                            1.0
# 860                                        0.0                            0.0
#
#       Regional indicator_Southeast Asia  \
# 1591                                0.0
# 1379                                0.0
# 414                                 0.0
# 704                                 0.0
# 755                                 0.0
# ...                                 ...
# 1638                                0.0
# 1095                                0.0
# 1130                                0.0
# 1294                                0.0
# 860                                 0.0
#
#       Regional indicator_Sub-Saharan Africa  Regional indicator_Western Europe
# 1591                                    0.0                                0.0
# 1379                                    1.0                                0.0
# 414                                     1.0                                0.0
# 704                                     0.0                                0.0
# 755                                     0.0                                0.0
# ...                                     ...                                ...
# 1638                                    1.0                                0.0
# 1095                                    0.0                                1.0
# 1130                                    1.0                                0.0
# 1294                                    0.0                                0.0
# 860                                     0.0                                0.0
#
# [1678 rows x 17 columns]

# %%
X_test
# Out:
#       Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 1005               8.374           0.891                            61.520
# 1078              10.046           0.930                            63.140
# 67                 9.402           0.698                            66.600
# 867               10.515           0.909                            72.580
# 650                9.585           0.671                            64.300
# ...                  ...             ...                               ...
# 294                8.276           0.765                            61.200
# 1746               9.279           0.824                            66.300
# 76                10.754           0.945                            72.400
# 205                8.998           0.805                            64.200
# 1653              11.488           0.915                            76.953
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 1005                         0.748      -0.155                      0.932
# 1078                         0.567      -0.295                      0.967
# 67                           0.614      -0.147                      0.865
# 867                          0.739       0.150                      0.849
# 650                          0.783      -0.238                      0.655
# ...                            ...         ...                        ...
# 294                          0.964       0.088                      0.821
# 1746                         0.800       0.161                      0.823
# 76                           0.935       0.274                      0.368
# 205                          0.877      -0.054                      0.868
# 1653                         0.927      -0.018                      0.082
#
#       Positive affect  Negative affect  \
# 1005            0.681            0.151
# 1078            0.621            0.254
# 67              0.625            0.437
# 867             0.698            0.409
# 650             0.559            0.243
# ...               ...              ...
# 294             0.799            0.408
# 1746            0.864            0.197
# 76              0.811            0.214
# 205             0.790            0.382
# 1653            0.751            0.144
#
#       Regional indicator_Commonwealth of Independent States  \
# 1005                                                1.0
# 1078                                                0.0
# 67                                                  1.0
# 867                                                 0.0
# 650                                                 1.0
# ...                                                 ...
# 294                                                 0.0
# 1746                                                0.0
# 76                                                  0.0
# 205                                                 0.0
# 1653                                                0.0
#
#       Regional indicator_East Asia  \
# 1005                           0.0
# 1078                           0.0
# 67                             0.0
# 867                            0.0
# 650                            0.0
# ...                            ...
# 294                            0.0
# 1746                           0.0
# 76                             0.0
# 205                            0.0
# 1653                           0.0
#
#       Regional indicator_Latin America and Caribbean  \
# 1005                                             0.0
# 1078                                             0.0
# 67                                               0.0
# 867                                              0.0
# 650                                              0.0
# ...                                              ...
# 294                                              0.0
# 1746                                             0.0
# 76                                               0.0
# 205                                              1.0
# 1653                                             0.0
#
#       Regional indicator_Middle East and North Africa  \
# 1005                                              0.0
# 1078                                              0.0
# 67                                                0.0
# 867                                               1.0
# 650                                               0.0
# ...                                               ...
# 294                                               0.0
# 1746                                              0.0
# 76                                                0.0
# 205                                               0.0
# 1653                                              0.0
#
#       Regional indicator_North America and ANZ  Regional indicator_South Asia  \
# 1005                                       0.0                            0.0
# 1078                                       0.0                            0.0
# 67                                         0.0                            0.0
# 867                                        0.0                            0.0
# 650                                        0.0                            0.0
# ...                                        ...                            ...
# 294                                        0.0                            0.0
# 1746                                       0.0                            1.0
# 76                                         1.0                            0.0
# 205                                        0.0                            0.0
# 1653                                       0.0                            0.0
#
#       Regional indicator_Southeast Asia  \
# 1005                                0.0
# 1078                                0.0
# 67                                  0.0
# 867                                 0.0
# 650                                 0.0
# ...                                 ...
# 294                                 1.0
# 1746                                0.0
# 76                                  0.0
# 205                                 0.0
# 1653                                1.0
#
#       Regional indicator_Sub-Saharan Africa  Regional indicator_Western Europe
# 1005                                    0.0                                0.0
# 1078                                    0.0                                0.0
# 67                                      0.0                                0.0
# 867                                     0.0                                0.0
# 650                                     0.0                                0.0
# ...                                     ...                                ...
# 294                                     0.0                                0.0
# 1746                                    0.0                                0.0
# 76                                      0.0                                0.0
# 205                                     0.0                                0.0
# 1653                                    0.0                                0.0
#
# [420 rows x 17 columns]

# %%
# On obtient un jeu final pour lequel la colonne 'Regional indicator' a bien été encodé
# Le dataset est prêt pour l'entraînement de modèles.

# %%
# Enregistrement des différents jeux pour le machine learning.
X_train.to_csv('../data/X_train.csv', index=False)
X_test.to_csv('../data/X_test.csv', index=False)
y_train.to_csv('../data/y_train.csv', index=False)
y_test.to_csv('../data/y_test.csv', index=False)
